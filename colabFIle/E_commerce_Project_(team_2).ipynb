# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
#"207c3389f3msh11486cf94cb0b1dp16574bjsn187424d96ce9"  //key not working --reached monthly limit :(--

# Got a new code - AM "0b9d3a7e8fmsh093104343dc2cbep100a65jsn8a5c61e641e3"

def walmart_search_by_keyword(keyword):
    url = "https://axesso-walmart-data-service.p.rapidapi.com/wlm/walmart-search-by-keyword"

    querystring = {
        "keyword": keyword,
        "page": "1",
        "sortBy": "best_match"
    }

    headers = {

        "X-RapidAPI-Key":   "dcd7cbe2demsh2762fda9960c05cp1fcc84jsnb21bf36130d9"  ,
        "X-RapidAPI-Host": "axesso-walmart-data-service.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        return None

# %%
############################only call this cell one per use##########################################
############################   50 call a month limit       ##########################################
data = walmart_search_by_keyword("Clothing")

#extracted_data = [extract_info(item) for item in data['item']['props']['pageProps']['initialData']['searchResult']['itemStacks'][0]['items']]
#display the first line price
#data['item']['props']['pageProps']['initialData']['searchResult']['itemStacks'][0]['items'][0]['priceInfo']['linePrice']

# %%
#in case the original data got all messed up we have data2
data2 = data


item_stacks = data['item']['props']['pageProps']['initialData']['searchResult']['itemStacks']
line_prices = []

names = []
avg_ratings = []
num_of_reviews = []
prices = []
item_data = {}
item_ids = []
item_avgs = []
item_num_of_reviews =[]
seller_names = []
availabilities = []

for stack in item_stacks:
    items = stack['items']
    for item in items:
        #had to bring exception (try catch)since some datas are empty
        try:
            #item id
            item_id = item['usItemId']
            item_ids.append(item_id)  # Add item_id to the list
            item_data['id'] = item_ids  # Store the list in item_data

            #seller names
            seller_name = item["sellerName"]
            seller_names.append(seller_name)
            item_data["seller_name"] = seller_names

            #price
            price = item["price"]
            prices.append(price)
            item_data['item_price'] = prices



            #line prices
            line_price = item['priceInfo']['linePrice']
            line_prices.append(line_price)
            item_data['Item_line_price'] = line_prices




            #line price display
            line_price_display = item['priceInfo']['linePriceDisplay']


            #availibily
            availabilities.append(not item['isOutOfStock'])
            item_data['availability'] = availabilities

            #average rating and total number of reviews
            avg_rating = item['rating']['averageRating']  # Corrected variable name
            item_avgs.append(avg_rating)
            item_data['avg_rating'] = item_avgs
            num_of_reviews = item['rating']['numberOfReviews']
            item_num_of_reviews.append(num_of_reviews)
            item_data['reviews'] = item_num_of_reviews
            #name of the item
            name = item['name']
            names.append(name)
            item_data['item_name'] = names

        #creating exception for cases with no values
        #in a way I am also eliminating these values from entering the dataframe
        except KeyError:
            print("None")
# Out:
# None
# None
# None
# None
# None

# %%
df = pd.DataFrame(item_data)
# Save the DataFrame to a CSV file
df.to_csv('item_data.csv', index="False")
df = df.set_index("id")

# %%
df
# Out:
#                         seller_name  item_price Item_line_price  availability  \
# id
# 1298698362              Walmart.com          11          $11.97          True
# 469570506                    Neleus          19          $19.54          True
# 601894059     Disney Shopping, Inc.          22          $22.99          True
# 736924347         Crazy Dog Tshirts          17          $17.99          True
# 3567947015              Walmart.com          13          $13.00          True
# 460997580               Walmart.com          26          $26.98          True
# 465429231      Gerber Childrenswear          15          $15.96          True
# 1139908677              Walmart.com          24          $24.99          True
# 119030235               Walmart.com          10          $10.00          True
# 3659259468              Walmart.com          20          $20.00          True
# 671683970         Crazy Dog Tshirts          18          $18.99          True
# 998393840     Disney Shopping, Inc.          22          $22.99          True
# 635590334                BHFO, Inc.          59          $59.99          True
# 547565755               Walmart.com          10          $10.00          True
# 1302170478              Walmart.com          11          $11.98          True
# 2859224965              Walmart.com          12          $12.48          True
# 1316084669                     FSLK          15          $15.99          True
# 617677506         Expedited Apparel          27          $27.99          True
# 1021174956              Walmart.com          10          $10.00          True
# 435719291               Walmart.com           9           $9.99          True
# 239884244     Disney Shopping, Inc.          22          $22.99          True
# 5048749419   Envisage Design Studio          29          $29.99          True
# 1030698094                     FSLK          15          $15.99          True
# 311154349      Clothing Shop Online          17          $17.88          True
# 481822563               Walmart.com           9           $9.98          True
# 1157308120              Walmart.com          15          $15.00          True
# 507956958               Walmart.com          13          $13.49          True
# 740453299               Walmart.com          13          $13.49          True
# 970977841               Walmart.com           5           $5.00          True
# 1211488049              Walmart.com          15          $15.00          True
# 5049997019               Azac Group          59          $59.99          True
# 495191768   Trenz Shirt Company Inc          15          $15.29          True
# 5982449                 Walmart.com          18          $18.98          True
# 220786480               Walmart.com           9           $9.88          True
# 245506959               Walmart.com          14          $14.96          True
# 480643522               Walmart.com          19          $19.98          True
# 1056473470              Walmart.com           8           $8.60          True
# 1901486304              Walmart.com          14          $14.98          True
# 1132721674              Walmart.com          12          $12.98          True
# 903059432               Walmart.com          16          $16.99          True
# 860912092               Walmart.com          22          $22.98          True
# 837340502   American Enterprise Inc          69          $69.99          True
# 495655652               Walmart.com           8           $8.98          True
# 514222468               Walmart.com          15          $15.00          True
# 3264828902              Walmart.com           7           $7.00          True
# 2080857682              Walmart.com          10          $10.00          True
# 938545778               Walmart.com           3           $3.98          True
# 889250624               Walmart.com          12          $12.98          True
# 1899169270              Walmart.com          15          $15.00          True
# 1864054424              Walmart.com          10          $10.00          True
#
#             avg_rating  reviews  \
# id
# 1298698362           4      164
# 469570506            0        0
# 601894059            5        1
# 736924347            0        0
# 3567947015           4       17
# 460997580            4      101
# 465429231            4       16
# 1139908677           4       17
# 119030235            4       31
# 3659259468           4       52
# 671683970            0        0
# 998393840            5        1
# 635590334            4        5
# 547565755            4       39
# 1302170478           4      503
# 2859224965           4      114
# 1316084669           4     1818
# 617677506            4     2641
# 1021174956           4      935
# 435719291            4      777
# 239884244            0        0
# 5048749419           0        0
# 1030698094           4      425
# 311154349            4     3120
# 481822563            4     3573
# 1157308120           4      639
# 507956958            4     7844
# 740453299            4     2876
# 970977841            4      656
# 1211488049           4      339
# 5049997019           0        0
# 495191768            5        1
# 5982449              4   112357
# 220786480            4     4401
# 245506959            4     1277
# 480643522            4    20787
# 1056473470           4     2278
# 1901486304           4       16
# 1132721674           4       59
# 903059432            4     2985
# 860912092            4    48861
# 837340502            4      439
# 495655652            4     1191
# 514222468            4       76
# 3264828902           4      132
# 2080857682           4      137
# 938545778            4     1350
# 889250624            4     8532
# 1899169270           4       50
# 1864054424           4      136
#
#                                                     item_name
# id
# 1298698362  Real Littles Collectible Micro Sanrio Hello Ki...
# 469570506   NELEUS Womens Compression Base Layer Dry Fit T...
# 601894059   Star Wars Tall Darth and Handsome Funny - Shor...
# 736924347   Womens Take A Hike Tshirt Funny Outdoor Advent...
# 3567947015  Time and Tru Women's Side Button Crew Neck Swe...
# 460997580   Signature by Levi Strauss & Co. Women's Simply...
# 465429231   Modern Moments by Gerber Baby and Toddler Boy ...
# 1139908677  Terra & Sky Women's Plus Size Quarter Snap Fau...
# 119030235   Modern Moments by Gerber Baby and Toddler Girl...
# 3659259468  Time and Tru Women's High Rise Stretch Faux Le...
# 671683970   Womens Fitness Tank Hide And Seek Champion Tan...
# 998393840   Star Wars Stormtrooper Employee of The Month -...
# 635590334   Steve Madden Women's Glacier Shield Winter Puf...
# 547565755   Modern Moments by Gerber Baby and Toddler Girl...
# 1302170478  George Men's Long Sleeve Flannel Shirt, Sizes ...
# 2859224965  George Men's Corduroy Shirt with Long Sleeves,...
# 1316084669  Fantaslook Sweatshirts for Women Crewneck Casu...
# 617677506   Galaxy by Harvic 3-Pack Women's Loose Fit Flee...
# 1021174956                    Time and Tru Women's Sweatshirt
# 435719291   Time and Tru Women's High Rise Knit Leggings, ...
# 239884244   Star Wars Logo Millennium Falcon and Death Sta...
# 5048749419  Envisage Virginia Hokies Football Enter Sandma...
# 1030698094  Fantaslook Sweatshirt for Women Long Sleeve Tu...
# 311154349   Gildan Unisex Heavy Blend Fleece Hooded Sweats...
# 481822563   Athletic Works Women's Dri More Core Athleisur...
# 1157308120  Time and Tru Women's High Rise Knit Leggings, ...
# 507956958   Fruit of the Loom EverSoft Fleece Elastic Bott...
# 740453299   Fruit of the Loom Men's EverSoft Fleece Crew S...
# 970977841   Time And Tru Women's High Rise Ankle Knit Legg...
# 1211488049        Reebok Men's Delta Logo Hoodie, Sizes S-3XL
# 5049997019  ProtectX 3-Pack High Visibility Heavy-duty Lon...
# 495191768   Women's Unisex Christian Loved John 3:16 Baseb...
# 5982449        Wrangler Men's and Big Men's Relaxed Fit Jeans
# 220786480   Time and Tru Women's High Rise Jeggings, 29" I...
# 245506959   Time and Tru Women's Faux Leather Leggings, Si...
# 480643522   Wrangler Men's and Big Men's Regular Fit Jeans...
# 1056473470  Joyspun Women’s Short Sleeve T-Shirt and Jogge...
# 1901486304  Time and Tru Women's Destination Graphic Sweat...
# 1132721674  Disney's 100th Anniversary Unisex Toddler Matc...
# 903059432   Fruit of the Loom EverSoft Fleece Full Zip Hoo...
# 860912092   Wrangler Men's and Big Men's Relaxed Fit Cargo...
# 837340502   Dr. Seuss Men's The Grinch Christmas Matching ...
# 495655652   Character Toddler Snug-Fit Pajama Set, 2 Piece...
# 514222468   Reebok Women's Elite Cozy Graphic Hoodie with ...
# 3264828902  Disney Mickey Mouse Toddler Unisex Long Sleeve...
# 2080857682  Nightmare Before Christmas Women's Christmas T...
# 938545778   Wonder Nation Boys Short Sleeve Kid Tough T-Sh...
# 889250624        George Men's and Big Men's Regular Fit Jeans
# 1899169270  Time and Tru Women's Velour Top and Pants Set,...
# 1864054424  Holiday Time Women's Merry Christmas Pajama Se...

# %%
data2
# Out:
# {'responseStatus': 'PRODUCT_FOUND_RESPONSE',
#  'responseMessage': 'Product successfully found!',
#  'sortStrategy': 'best_match',
#  'domainCode': 'com',
#  'keyword': 'Clothing',
#  'item': {'assetPrefix': 'https://i5.walmartimages.com/dfw/63fd9f59-397c/135dd224-4517-49f9-9614-fc46d13dee3a/v2/en-US',
#   'dynamicIds': ['613480',
#    '554651',
#    '484962',
#    '161874',
#    '966165',
#    '763357',
#    '823157',
#    '350610',
#    '714438',
#    '533161',
#    '57289',
#    '305261',
#    '986809',
#    '721073'],
#   'query': {'query': 'Clothing', 'sort': 'best_match', 'page': '1'},
#   'appGip': True,
#   'buildId': 'production_20231113T233804906Z-en-US',
#   'locale': 'en',
#   'props': {'pageProps': {'initialData': {'searchResult': {'title': 'Results for "Clothing"',
#       'aggregatedCount': 205556,
#       'debug': {'sisUrl': 'http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=Clothing&facet=&stores=2648&cat_id=&sort=best_match&page=1&min_price=&max_price=&spelling=true&ptss=&trsp=&isMoreOptionsTileEnabled=true&autoOptIn=false&prg=desktop&storeSlotBooked=&stateOrProvinceCode=CA&ps=40&zipcode=94142&recall_set=&pageType=SearchPage&inCatchment=false&latitude=37.7819&longitude=-122.4146&extended_zipcode=94142&addressId=&customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&pickupStore=2648&deliveryStore=&subIntentSource=LS',
#        'adsUrl': 'http://swag-wmt.prod.walmart.com/fs?storeSlotBooked=&prg=desktop&limit=40&query=Clothing&cat_id=&facet=&page=1&ps=10&min_price=&max_price=&sort=best_match&spelling=true&recall_set=&ptss=&pageType=SearchPage&trsp=&zipcode=94142&stores=2648&stateOrProvinceCode=CA&latitude=37.7819&longitude=-122.4146&extended_zipcode=94142&addressId=&inCatchment=false&autoOptIn=false&isMoreOptionsTileEnabled=true&customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&pickupStore=2648&deliveryStore=&subIntentSource=LS',
#        'presoDebugInformation': [{'explainerToolsResponse': None}]},
#       'itemStacks': [{'meta': {'adsBeacon': {'adUuid': 'c0f06591-4248-4dab-8051-9fa3519b752c',
#           'moduleInfo': '{"adUuid":"c0f06591-4248-4dab-8051-9fa3519b752c","facet":false,"intent":true,"affinity":"default","sorting":"best_match","bucketId":"ace_3121|coldstart_off|search_\\"search_ranking_recency_ce\\"","engagementTraffic":"head_torso","sessionTraffic":"torso","ghost":[]}',
#           'max_ads': 10},
#          'query': 'Clothing',
#          'stackId': 0,
#          'stackType': 'DEFAULT',
#          'title': 'Results for "Clothing"',
#          'layoutEnum': 'GRID',
#          'totalItemCount': 205556,
#          'totalItemCountDisplay': '(1000+)',
#          'borderColor': None,
#          'isPartialResult': False,
#          'subTitle': None,
#          'queryUsedForSearchResults': None,
#          'stackName': None,
#          'iconUrl': None,
#          'titleKey': None,
#          'spBeaconInfo': None},
#         'title': 'Results for "Clothing"',
#         'totalItemCountDisplay': '(1000+)',
#         'count': 205556,
#         'items': [{'__typename': 'Product',
#           'availabilityStatusDisplayValue': 'In stock',
#           'externalInfoUrl': '',
#           'canonicalUrl': '/ip/Real-Littles-Collectible-Micro-Sanrio-Hello-Kitty-and-Friends-Backpacks-Ages-6/1298698362',
#           'canAddToCart': False,
#           'showOptions': False,
#           'description': '',
#           'flag': '',
#           'fulfillmentBadges': [],
#           'fulfillmentType': 'FC',
#           'id': '5TUXERCTK936',
#           'usItemId': '1298698362',
#           'image': 'https://i5.walmartimages.com/seo/Real-Littles-Collectible-Micro-Sanrio-Hello-Kitty-and-Friends-Backpacks-Ages-6_85291b02-8e99-4724-aedf-a07a2f73d932.536949e264f7247ce750823aff371ca1.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#           'isOutOfStock': False,
#           'name': 'Real Littles Collectible Micro Sanrio Hello Kitty and Friends Backpacks  Ages 6+',
#           'price': 11,
#           'preOrder': {'isPreOrder': False,
#            'streetDateDisplayable': None,
#            'streetDateType': None,
#            'streetDate': None},
#           'priceInfo': {'itemPrice': '',
#            'linePrice': '$11.97',
#            'wasPrice': '',
#            'unitPrice': '',
#            'shipPrice': '',
#            'minPriceForVariant': '',
#            'subscriptionPrice': '',
#            'subscriptionString': '',
#            'priceDisplayCondition': '',
#            'finalCostByWeight': False,
#            'submapType': '',
#            'priceRangeString': '',
#            'linePriceDisplay': '$11.97',
#            'eaPricingPreText': '',
#            'memberPriceString': '',
#            'subscriptionPercentage': None,
#            'savingsAmt': 0,
#            'minPrice': 0,
#            'savings': '',
#            'subscriptionDualPrice': None,
#            'eaPricingText': ''},
#           'rating': {'averageRating': 4, 'numberOfReviews': 164},
#           'salesUnit': 'EACH',
#           'variantList': [],
#           'isVariantTypeSwatch': False,
#           'brand': 'Real Littles',
#           'offerId': 'E4B60DBEFA1645DCAE262E93DD798357',
#           'isAtfMarker': False,
#           'sellerId': 'F55CDC31AB754BB68FE0B39041159D63',
#           'sellerName': 'Walmart.com',
#           'sponsoredProduct': {'spQs': 'yAELEwRXBEjnDXyY_j5yDMxaV6EiClA3T82bchrGFfyX7qjYi69RBGnqwqZk0aBd2FStYtJetOih-jVp5sndKFGXEtlEp97vHzKt1l7AbKHJp-F1VJHumdAPK15-2r1qEaQOn-Fyb_SytiW-l1l7RpJeIJrW3DDYGj8joYaxC-vUbNQcqqoGglTuMh92vLyXZOVKVN7iZqSiPWzY2i5thOqeUkuzemiGjAkJEVPvpWU',
#            'clickBeacon': 'https://wrd.walmart.com/track?adUid=c0f06591-4248-4dab-8051-9fa3519b752c&pgId=clothing&spQs=yAELEwRXBEjnDXyY_j5yDMxaV6EiClA3T82bchrGFfyX7qjYi69RBGnqwqZk0aBd2FStYtJetOih-jVp5sndKFGXEtlEp97vHzKt1l7AbKHJp-F1VJHumdAPK15-2r1qEaQOn-Fyb_SytiW-l1l7RpJeIJrW3DDYGj8joYaxC-vUbNQcqqoGglTuMh92vLyXZOVKVN7iZqSiPWzY2i5thOqeUkuzemiGjAkJEVPvpWU&storeId=2648&pt=search&mloc=sp-search-middle&bkt=ace_3121%7Ccoldstart_off%7Csearch_%22search_ranking_recency_ce%22&pltfm=desktop&rdf=0&plmt=__plmt__&eventST=__eventST__&pos=__pos__&bt=__bt__&tax=5438_133162_8956587_6248847&et=head_torso&st=torso',
#            'spTags': None,
#            'viewBeacon': None},
#           'quickShop': None,
#           'numberOfReviews': 164,
#           'imageInfo': {'id': '04E6816FEB804B4280279EB1AD8D7F6D',
#            'name': 'Real-Littles-Collectible-Micro-Sanrio-Hello-Kitty-and-Friends-Backpacks-Ages-6_85291b02-8e99-4724-aedf-a07a2f73d932.536949e264f7247ce750823aff371ca1.jpeg',
#            'thumbnailUrl': 'https://i5.walmartimages.com/seo/Real-Littles-Collectible-Micro-Sanrio-Hello-Kitty-and-Friends-Backpacks-Ages-6_85291b02-8e99-4724-aedf-a07a2f73d932.536949e264f7247ce750823aff371ca1.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#            'size': '290-392'},
#           'type': 'REGULAR',
#           'moqText': None,
#           'specialBuy': False,
#           'pac': None,
#           'priceFlip': False,
#           'earlyAccessEvent': False,
#           'fulfillmentIcon': {'key': 'SAVE_WITH_W_PLUS', 'label': 'Save with'},
#           'groupMetaData': {'groupType': None,
#            'groupSubType': None,
#            'numberOfComponents': 0,
#            'groupComponents': None},
#           'petRx': {'eligible': False, 'singleDispense': None},
#           'pglsCondition': None,
#           'preownedCondition': 'None',
#           'imageName': 'Real-Littles-Collectible-Micro-Sanrio-Hello-Kitty-and-Friends-Backpacks-Ages-6_85291b02-8e99-4724-aedf-a07a2f73d932.536949e264f7247ce750823aff371ca1.jpeg',
#           'fulfillmentBadgeGroups': [{'text': 'Shipping, arrives ',
#             'slaText': 'in 3+ days',
#             'isSlaTextBold': True,
#             'templates': None,
#             'className': 'dark-gray'}],
#           'weightIncrement': 1,
#           'shortDescription': None,
#           'isEarlyAccessItem': False,
#           'fulfillmentTitle': 'title_shipToHome_not_available',
#           'buyBoxSuppression': False,
#           'vision': {'ageGroup': None, 'visionCenterApproved': False},
#           'badge': {'text': '',
#            'id': '',
#            'type': '',
#            'key': '',
#            'bundleId': ''},
#           'classType': 'REGULAR',
#           'annualEventV2': False,
#           'rewards': None,
#           'seeShippingEligibility': False,
#           'itemType': None,
#           'topResult': None,
#           'isPreowned': False,
#           'imageID': '04E6816FEB804B4280279EB1AD8D7F6D',
#           'aspectInfo': {'name': None,
#            'header': None,
#            'id': None,
#            'snippet': None},
#           'externalInfo': None,
#           'variantCriteria': [],
#           'productLocation': None,
#           'subscription': {'__typename': 'SubscriptionData',
#            'subscriptionEligible': True},
#           'salesUnitType': 'EACH',
#           'additionalOfferCount': 2,
#           'isSponsoredFlag': True,
#           'averageRating': 4.1,
#           'arExperiences': {'isARHome': False,
#            'isZeekit': False,
#            'isAROptical': False},
#           'fulfillmentSummary': [{'storeId': '0', 'deliveryDate': None}],
#           'hasCarePlans': False,
#           'imageSize': '290-392',
#           'promoDiscount': None,
#           'quickShopCTALabel': None,
#           'availabilityInNearbyStore': None,
#           'checkStoreAvailabilityATC': False,
#           'eventAttributes': {'priceFlip': False, 'specialBuy': False},
#           'showAtc': False,
#           'similarItems': False,
#           'newConditionProductId': None,
#           'keyAttributes': [],
#           'annualEvent': False,
#           'badges': {'flags': None,
#            'tags': [{'__typename': 'BaseBadge',
#              'key': 'SAVE_WITH_W_PLUS',
#              'text': 'Save with',
#              'type': 'ICON'}],
#            'groups': [{'__typename': 'UnifiedBadgeGroup',
#              'name': 'fulfillment',
#              'members': [{'__typename': 'BadgeGroupMember',
#                'id': 'L1053',
#                'key': 'FF_SHIPPING',
#                'memberType': 'badge',
#                'otherInfo': None,
#                'rank': 1,
#                'slaText': 'in 3+ days',
#                'styleId': 'FF_STYLE',
#                'text': 'Shipping, arrives ',
#                'type': 'LABEL',
#                'templates': None,
#                'badgeContent': None}]},
#             {'__typename': 'UnifiedBadgeGroup',
#              'name': 'subscription',
#              'members': [{'__typename': 'BadgeGroupMember',
#                'id': 'L1092',
#                'key': 'SUBSCRIPTION_ELIGIBLE',
#                'memberType': 'badge',
#                'otherInfo': None,
#                'rank': 1,
#                'slaText': None,
#                'styleId': 'VECTOR_WITH_NO_BG',
#                'text': 'New! Get auto-delivery',
#                'type': 'ICON',
#                'templates': None,
#                'badgeContent': None}]}]},
#           'snapEligible': False,
#           'showBuyNow': False,
#           'showExploreOtherConditionsCTA': False,
#           'availabilityStatusV2': {'display': 'In stock', 'value': 'IN_STOCK'},
#           'category': {'path': None},
#           'shouldLazyLoad': False},
#          {'__typename': 'Product',
#           'availabilityStatusDisplayValue': 'In stock',
#           'externalInfoUrl': '',
#           'canonicalUrl': '/ip/NELEUS-Womens-Compression-Base-Layer-Dry-Fit-Tank-Top-3-Pack-Blackish-Green-Purple-Pink-US-Size-XS/469570506',
#           'canAddToCart': False,
#           'showOptions': False,
#           'description': '',
#           'flag': '',
#           'fulfillmentBadges': [],
#           'fulfillmentType': 'FC',
#           'id': '7GEOKYRAQAN7',
#           'usItemId': '469570506',
#           'image': 'https://i5.walmartimages.com/seo/NELEUS-Womens-Compression-Base-Layer-Dry-Fit-Tank-Top-3-Pack-Blackish-Green-Purple-Pink-US-Size-XS_3e034d9a-00d0-4576-b91b-aad01eb040e1.38cc188e5be2037a15f580ddaf5fbd67.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#           'isOutOfStock': False,
#           'name': 'NELEUS Womens Compression Base Layer Dry Fit Tank Top 3 Pack,Blackish Green+Purple+Pink,US Size XS',
#           'price': 19,
#           'preOrder': {'isPreOrder': False,
#            'streetDateDisplayable': None,
#            'streetDateType': None,
#            'streetDate': None},
#           'priceInfo': {'itemPrice': '$48.00',
#            'linePrice': '$19.54',
#            'wasPrice': '$48.00',
#            'unitPrice': '',
#            'shipPrice': '',
#            'minPriceForVariant': '',
#            'subscriptionPrice': '',
#            'subscriptionString': '',
#            'priceDisplayCondition': '',
#            'finalCostByWeight': False,
#            'submapType': '',
#            'priceRangeString': 'Options from $19.54 – $21.96',
#            'linePriceDisplay': 'Now $19.54',
#            'eaPricingPreText': '',
#            'memberPriceString': '',
#            'subscriptionPercentage': None,
#            'savingsAmt': 28.46,
#            'minPrice': 19.54,
#            'savings': 'SAVE $28.46',
#            'subscriptionDualPrice': None,
#            'eaPricingText': ''},
#           'rating': {'averageRating': 0, 'numberOfReviews': 0},
#           'salesUnit': 'EACH',
#           'variantList': [],
#           'isVariantTypeSwatch': False,
#           'brand': 'NELEUS',
#           'offerId': '28917ACAE34E43B99CDEDB395FC20763',
#           'isAtfMarker': False,
#           'sellerId': '3E545B7EB83944BE83ECCBE656912B65',
#           'sellerName': 'Neleus',
#           'sponsoredProduct': {'spQs': 'XdjraFC-Qgt4iItWMPQZxvpPis_9KmSnTP6cgq5rmtBWZCkHTZzc9y3R0bY4N4c-U0lQeHj4QX6cLmRVrbAMu-f6KOXU8EfvbK2pSRsI46xb2Qh8w-e2ntv8PmUDylvwZC_6qnVLe1SaRpagz2_qoBoXJhPCfT-sYpRyAZKlkRlbTJC01EpGw-nmu3i7Ep6wkWp_6oFq82PTlPU2rak16G7PsNtvbRQ5MfQ0hp5k7Gs',
#            'clickBeacon': 'https://wrd.walmart.com/track?adUid=c0f06591-4248-4dab-8051-9fa3519b752c&pgId=clothing&spQs=XdjraFC-Qgt4iItWMPQZxvpPis_9KmSnTP6cgq5rmtBWZCkHTZzc9y3R0bY4N4c-U0lQeHj4QX6cLmRVrbAMu-f6KOXU8EfvbK2pSRsI46xb2Qh8w-e2ntv8PmUDylvwZC_6qnVLe1SaRpagz2_qoBoXJhPCfT-sYpRyAZKlkRlbTJC01EpGw-nmu3i7Ep6wkWp_6oFq82PTlPU2rak16G7PsNtvbRQ5MfQ0hp5k7Gs&storeId=2648&pt=search&mloc=sp-search-middle&bkt=ace_3121%7Ccoldstart_off%7Csearch_%22search_ranking_recency_ce%22&pltfm=desktop&rdf=0&plmt=__plmt__&eventST=__eventST__&pos=__pos__&bt=__bt__&tax=5438_133162_8956587_6248847&et=head_torso&st=torso',
#            'spTags': None,
#            'viewBeacon': None},
#           'quickShop': None,
#           'numberOfReviews': None,
#           'imageInfo': {'id': '0F4B7BA366594E42ACA4A9836F1E5905',
#            'name': 'NELEUS-Womens-Compression-Base-Layer-Dry-Fit-Tank-Top-3-Pack-Blackish-Green-Purple-Pink-US-Size-XS_3e034d9a-00d0-4576-b91b-aad01eb040e1.38cc188e5be2037a15f580ddaf5fbd67.jpeg',
#            'thumbnailUrl': 'https://i5.walmartimages.com/seo/NELEUS-Womens-Compression-Base-Layer-Dry-Fit-Tank-Top-3-Pack-Blackish-Green-Purple-Pink-US-Size-XS_3e034d9a-00d0-4576-b91b-aad01eb040e1.38cc188e5be2037a15f580ddaf5fbd67.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#            'size': '290-392'},
#           'type': 'VARIANT',
#           'moqText': None,
#           'specialBuy': False,
#           'pac': None,
#           'priceFlip': False,
#           'earlyAccessEvent': False,
#           'fulfillmentIcon': {'key': 'SAVE_WITH_W_PLUS', 'label': 'Save with'},
#           'groupMetaData': {'groupType': None,
#            'groupSubType': None,
#            'numberOfComponents': 0,
#            'groupComponents': None},
#           'petRx': {'eligible': False, 'singleDispense': None},
#           'pglsCondition': None,
#           'preownedCondition': 'None',
#           'imageName': 'NELEUS-Womens-Compression-Base-Layer-Dry-Fit-Tank-Top-3-Pack-Blackish-Green-Purple-Pink-US-Size-XS_3e034d9a-00d0-4576-b91b-aad01eb040e1.38cc188e5be2037a15f580ddaf5fbd67.jpeg',
#           'fulfillmentBadgeGroups': [{'text': 'Shipping, arrives ',
#             'slaText': 'in 2 days',
#             'isSlaTextBold': True,
#             'templates': None,
#             'className': 'dark-gray'}],
#           'weightIncrement': 1,
#           'shortDescription': None,
#           'isEarlyAccessItem': False,
#           'fulfillmentTitle': 'title_shipToHome_not_available',
#           'buyBoxSuppression': False,
#           'vision': {'ageGroup': None, 'visionCenterApproved': False},
#           'badge': {'text': '',
#            'id': '',
#            'type': '',
#            'key': '',
#            'bundleId': ''},
#           'classType': 'VARIANT',
#           'annualEventV2': False,
#           'rewards': None,
#           'seeShippingEligibility': False,
#           'itemType': None,
#           'topResult': None,
#           'isPreowned': False,
#           'imageID': '0F4B7BA366594E42ACA4A9836F1E5905',
#           'aspectInfo': {'name': None,
#            'header': None,
#            'id': None,
#            'snippet': None},
#           'externalInfo': None,
#           'variantCriteria': [],
#           'productLocation': None,
#           'subscription': {'__typename': 'SubscriptionData',
#            'subscriptionEligible': False},
#           'salesUnitType': 'EACH',
#           'additionalOfferCount': None,
#           'isSponsoredFlag': True,
#           'averageRating': None,
#           'arExperiences': {'isARHome': False,
#            'isZeekit': False,
#            'isAROptical': False},
#           'fulfillmentSummary': [{'storeId': '0', 'deliveryDate': None}],
#           'hasCarePlans': False,
#           'imageSize': '290-392',
#           'promoDiscount': None,
#           'quickShopCTALabel': None,
#           'availabilityInNearbyStore': None,
#           'checkStoreAvailabilityATC': False,
#           'eventAttributes': {'priceFlip': False, 'specialBuy': False},
#           'showAtc': False,
#           'similarItems': False,
#           'newConditionProductId': None,
#           'keyAttributes': [],
#           'annualEvent': False,
#           'badges': {'flags': None,
#            'tags': [{'__typename': 'BaseBadge',
#              'key': 'SAVE_WITH_W_PLUS',
#              'text': 'Save with',
#              'type': 'ICON'}],
#            'groups': [{'__typename': 'UnifiedBadgeGroup',
#              'name': 'fulfillment',
#              'members': [{'__typename': 'BadgeGroupMember',
#                'id': 'L1053',
#                'key': 'FF_SHIPPING',
#                'memberType': 'badge',
#                'otherInfo': None,
#                'rank': 1,
#                'slaText': 'in 2 days',
#                'styleId': 'FF_STYLE',
#                'text': 'Shipping, arrives ',
#                'type': 'LABEL',
#                'templates': None,
#                'badgeContent': None}]}]},
#           'snapEligible': False,
#           'showBuyNow': False,
#           'showExploreOtherConditionsCTA': False,
#           'availabilityStatusV2': {'display': 'In stock', 'value': 'IN_STOCK'},
#           'category': {'path': None},
#           'shouldLazyLoad': False},
#          {'__typename': 'Product',
#           'availabilityStatusDisplayValue': 'In stock',
#           'externalInfoUrl': '',
#           'canonicalUrl': '/ip/Star-Wars-Tall-Darth-and-Handsome-Funny-Short-Sleeve-Cotton-T-Shirt-for-Adults-Customized-Royal-Heather/601894059',
#           'canAddToCart': False,
#           'showOptions': False,
#           'description': '',
#           'flag': '',
#           'fulfillmentBadges': [],
#           'fulfillmentType': 'MARKETPLACE',
#           'id': '6EZLUM2ZXBDZ',
#           'usItemId': '601894059',
#           'image': 'https://i5.walmartimages.com/seo/Star-Wars-Tall-Darth-and-Handsome-Funny-Short-Sleeve-Cotton-T-Shirt-for-Adults-Customized-Royal-Heather_30e1793e-7fa3-4468-8caf-bd58d9779fd8.2106433b2f88a4c49709b4e0ce139589.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#           'isOutOfStock': False,
#           'name': 'Star Wars Tall Darth and Handsome Funny - Short Sleeve Cotton T-Shirt for Adults -Customized-Royal Heather',
#           'price': 22,
#           'preOrder': {'isPreOrder': False,
#            'streetDateDisplayable': None,
#            'streetDateType': None,
#            'streetDate': None},
#           'priceInfo': {'itemPrice': '',
#            'linePrice': '$22.99',
#            'wasPrice': '',
#            'unitPrice': '',
#            'shipPrice': '',
#            'minPriceForVariant': '',
#            'subscriptionPrice': '',
#            'subscriptionString': '',
#            'priceDisplayCondition': '',
#            'finalCostByWeight': False,
#            'submapType': '',
#            'priceRangeString': '',
#            'linePriceDisplay': '$22.99',
#            'eaPricingPreText': '',
#            'memberPriceString': '',
#            'subscriptionPercentage': None,
#            'savingsAmt': 0,
#            'minPrice': 0,
#            'savings': '',
#            'subscriptionDualPrice': None,
#            'eaPricingText': ''},
#           'rating': {'averageRating': 5, 'numberOfReviews': 1},
#           'salesUnit': 'EACH',
#           'variantList': [],
#           'isVariantTypeSwatch': False,
#           'brand': 'Star Wars',
#           'offerId': 'DB56C9702AA74FF29120747EBC4B127A',
#           'isAtfMarker': False,
#           'sellerId': '82963580584F425F8EF0602274086647',
#           'sellerName': 'Disney Shopping, Inc.',
#           'sponsoredProduct': {'spQs': 'cTIftC1Zo9l1wwjw48ZLVxhw57l3tOlCI9qYqe7gJN0JBQeizK1Sb4rLfCD5JkHea7sOO4Qv6HbbNzlGrHnkl67lYvcPm3BoUcce9cLTTtyjd8mXrauGFcVnXhlcd6LuAX4BnLVDHRUIwOOsgYse6XhEWj6hZyP8SiPWf7mTc8CLY_CfABXRXIcPcCU4gX4XN2UTE_gxBOGCrtwCz67v7du_EyYACHduL7UN7Wscj4A',
#            'clickBeacon': 'https://wrd.walmart.com/track?adUid=c0f06591-4248-4dab-8051-9fa3519b752c&pgId=clothing&spQs=cTIftC1Zo9l1wwjw48ZLVxhw57l3tOlCI9qYqe7gJN0JBQeizK1Sb4rLfCD5JkHea7sOO4Qv6HbbNzlGrHnkl67lYvcPm3BoUcce9cLTTtyjd8mXrauGFcVnXhlcd6LuAX4BnLVDHRUIwOOsgYse6XhEWj6hZyP8SiPWf7mTc8CLY_CfABXRXIcPcCU4gX4XN2UTE_gxBOGCrtwCz67v7du_EyYACHduL7UN7Wscj4A&storeId=2648&pt=search&mloc=sp-search-middle&bkt=ace_3121%7Ccoldstart_off%7Csearch_%22search_ranking_recency_ce%22&pltfm=desktop&rdf=0&plmt=__plmt__&eventST=__eventST__&pos=__pos__&bt=__bt__&tax=5438_133162_8956587_6248847&et=head_torso&st=torso',
#            'spTags': None,
#            'viewBeacon': None},
#           'quickShop': None,
#           'numberOfReviews': 1,
#           'imageInfo': {'id': '3674D57F321D41ADBB9D3DED5499DFBC',
#            'name': 'Star-Wars-Tall-Darth-and-Handsome-Funny-Short-Sleeve-Cotton-T-Shirt-for-Adults-Customized-Royal-Heather_30e1793e-7fa3-4468-8caf-bd58d9779fd8.2106433b2f88a4c49709b4e0ce139589.jpeg',
#            'thumbnailUrl': 'https://i5.walmartimages.com/seo/Star-Wars-Tall-Darth-and-Handsome-Funny-Short-Sleeve-Cotton-T-Shirt-for-Adults-Customized-Royal-Heather_30e1793e-7fa3-4468-8caf-bd58d9779fd8.2106433b2f88a4c49709b4e0ce139589.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#            'size': '290-392'},
#           'type': 'VARIANT',
#           'moqText': None,
#           'specialBuy': False,
#           'pac': None,
#           'priceFlip': False,
#           'earlyAccessEvent': False,
#           'groupMetaData': {'groupType': None,
#            'groupSubType': None,
#            'numberOfComponents': 0,
#            'groupComponents': None},
#           'petRx': {'eligible': False, 'singleDispense': None},
#           'pglsCondition': None,
#           'preownedCondition': 'None',
#           'imageName': 'Star-Wars-Tall-Darth-and-Handsome-Funny-Short-Sleeve-Cotton-T-Shirt-for-Adults-Customized-Royal-Heather_30e1793e-7fa3-4468-8caf-bd58d9779fd8.2106433b2f88a4c49709b4e0ce139589.jpeg',
#           'fulfillmentBadgeGroups': [{'text': 'Free shipping, arrives ',
#             'slaText': 'in 3+ days',
#             'isSlaTextBold': True,
#             'templates': None,
#             'className': 'dark-gray'}],
#           'weightIncrement': 1,
#           'shortDescription': None,
#           'isEarlyAccessItem': False,
#           'fulfillmentTitle': 'title_shipToHome_not_available',
#           'buyBoxSuppression': False,
#           'vision': {'ageGroup': None, 'visionCenterApproved': False},
#           'badge': {'text': '',
#            'id': '',
#            'type': '',
#            'key': '',
#            'bundleId': ''},
#           'classType': 'VARIANT',
#           'annualEventV2': False,
#           'rewards': None,
#           'seeShippingEligibility': False,
#           'itemType': None,
#           'topResult': None,
#           'isPreowned': False,
#           'imageID': '3674D57F321D41ADBB9D3DED5499DFBC',
#           'aspectInfo': {'name': None,
#            'header': None,
#            'id': None,
#            'snippet': None},
#           'externalInfo': None,
#           'variantCriteria': [],
#           'productLocation': None,
#           'subscription': {'__typename': 'SubscriptionData',
#            'subscriptionEligible': False},
#           'salesUnitType': 'EACH',
#           'additionalOfferCount': None,
#           'isSponsoredFlag': True,
#           'averageRating': 5,
#           'arExperiences': {'isARHome': False,
#            'isZeekit': False,
#            'isAROptical': False},
#           'fulfillmentSummary': [{'storeId': '0', 'deliveryDate': None}],
#           'hasCarePlans': False,
#           'imageSize': '290-392',
#           'promoDiscount': None,
#           'quickShopCTALabel': None,
#           'availabilityInNearbyStore': None,
#           'checkStoreAvailabilityATC': False,
#           'eventAttributes': {'priceFlip': False, 'specialBuy': False},
#           'showAtc': False,
#           'similarItems': False,
#           'newConditionProductId': None,
#           'keyAttributes': [],
#           'annualEvent': False,
#           'badges': {'flags': None,
#            'tags': [],
#            'groups': [{'__typename': 'UnifiedBadgeGroup',
#              'name': 'fulfillment',
#              'members': [{'__typename': 'BadgeGroupMember',
#                'id': 'L1053',
#                'key': 'FF_SHIPPING',
#                'memberType': 'badge',
#                'otherInfo': None,
#                'rank': 1,
#                'slaText': 'in 3+ days',
#                'styleId': 'FF_STYLE',
#                'text': 'Free shipping, arrives ',
#                'type': 'LABEL',
#                'templates': None,
#                'badgeContent': None}]}]},
#           'snapEligible': False,
#           'showBuyNow': False,
#           'showExploreOtherConditionsCTA': False,
#           'availabilityStatusV2': {'display': 'In stock', 'value': 'IN_STOCK'},
#           'category': {'path': None},
#           'shouldLazyLoad': False},
#          {'__typename': 'Product',
#           'availabilityStatusDisplayValue': 'In stock',
#           'externalInfoUrl': '',
#           'canonicalUrl': '/ip/Womens-Take-A-Hike-Tshirt-Funny-Outdoor-Adventure-Camping-Graphic-Tee-Heather-Navy-L-Womens-Graphic-Tees/736924347',
#           'canAddToCart': False,
#           'showOptions': False,
#           'description': '',
#           'flag': '',
#           'fulfillmentBadges': [],
#           'fulfillmentType': 'MARKETPLACE',
#           'id': '3TP42001TG2T',
#           'usItemId': '736924347',
#           'image': 'https://i5.walmartimages.com/seo/Womens-Take-A-Hike-Tshirt-Funny-Outdoor-Adventure-Camping-Graphic-Tee-Heather-Navy-L-Womens-Graphic-Tees_6e00e842-aabc-41ae-9df7-493b18f22e64.f46cbf1b0debfdc4963b19b715f03a8f.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#           'isOutOfStock': False,
#           'name': 'Womens Take A Hike Tshirt Funny Outdoor Adventure Camping Graphic Tee (Heather Navy) - L Womens Graphic Tees',
#           'price': 17,
#           'preOrder': {'isPreOrder': False,
#            'streetDateDisplayable': None,
#            'streetDateType': None,
#            'streetDate': None},
#           'priceInfo': {'itemPrice': '',
#            'linePrice': '$17.99',
#            'wasPrice': '',
#            'unitPrice': '',
#            'shipPrice': '',
#            'minPriceForVariant': '',
#            'subscriptionPrice': '',
#            'subscriptionString': '',
#            'priceDisplayCondition': '',
#            'finalCostByWeight': False,
#            'submapType': '',
#            'priceRangeString': 'More options from $13.99',
#            'linePriceDisplay': '$17.99',
#            'eaPricingPreText': '',
#            'memberPriceString': '',
#            'subscriptionPercentage': None,
#            'savingsAmt': 0,
#            'minPrice': 13.99,
#            'savings': '',
#            'subscriptionDualPrice': None,
#            'eaPricingText': ''},
#           'rating': {'averageRating': 0, 'numberOfReviews': 0},
#           'salesUnit': 'EACH',
#           'variantList': [],
#           'isVariantTypeSwatch': False,
#           'brand': 'Crazy Dog T-Shirts',
#           'offerId': '82EFFD4865BA4F998379FD8EC7F8E951',
#           'isAtfMarker': False,
#           'sellerId': '84526124A461423D842ACB02B235ECF3',
#           'sellerName': 'Crazy Dog Tshirts',
#           'sponsoredProduct': {'spQs': 'ZfNYfUXty8Y02kvX81mc5eL02LT1rkiP9P_1pY5VIY7KkQHeE1GVBt-hZ321cC_2NMKWsKDsUth2F-9MsLjhjUSOnp-nQvJhxj9szvXd7OG_pfnlPgjmuRF4JKKJbOE-rtlbk8nNMshiaxjtpIji3I5ocLOHOQBG3WXqGDdSmMyLY_CfABXRXIcPcCU4gX4XN2UTE_gxBOGCrtwCz67v7du_EyYACHduL7UN7Wscj4A',
#            'clickBeacon': 'https://wrd.walmart.com/track?adUid=c0f06591-4248-4dab-8051-9fa3519b752c&pgId=clothing&spQs=ZfNYfUXty8Y02kvX81mc5eL02LT1rkiP9P_1pY5VIY7KkQHeE1GVBt-hZ321cC_2NMKWsKDsUth2F-9MsLjhjUSOnp-nQvJhxj9szvXd7OG_pfnlPgjmuRF4JKKJbOE-rtlbk8nNMshiaxjtpIji3I5ocLOHOQBG3WXqGDdSmMyLY_CfABXRXIcPcCU4gX4XN2UTE_gxBOGCrtwCz67v7du_EyYACHduL7UN7Wscj4A&storeId=2648&pt=search&mloc=sp-search-middle&bkt=ace_3121%7Ccoldstart_off%7Csearch_%22search_ranking_recency_ce%22&pltfm=desktop&rdf=0&plmt=__plmt__&eventST=__eventST__&pos=__pos__&bt=__bt__&tax=5438_133162_8956587_6248847&et=head_torso&st=torso',
#            'spTags': None,
#            'viewBeacon': None},
#           'quickShop': None,
#           'numberOfReviews': None,
#           'imageInfo': {'id': '309245D66D514A708F547CB70FD2EBD2',
#            'name': 'Womens-Take-A-Hike-Tshirt-Funny-Outdoor-Adventure-Camping-Graphic-Tee-Heather-Navy-L-Womens-Graphic-Tees_6e00e842-aabc-41ae-9df7-493b18f22e64.f46cbf1b0debfdc4963b19b715f03a8f.jpeg',
#            'thumbnailUrl': 'https://i5.walmartimages.com/seo/Womens-Take-A-Hike-Tshirt-Funny-Outdoor-Adventure-Camping-Graphic-Tee-Heather-Navy-L-Womens-Graphic-Tees_6e00e842-aabc-41ae-9df7-493b18f22e64.f46cbf1b0debfdc4963b19b715f03a8f.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#            'size': '290-392'},
#           'type': 'VARIANT',
#           'moqText': None,
#           'specialBuy': False,
#           'pac': None,
#           'priceFlip': False,
#           'earlyAccessEvent': False,
#           'groupMetaData': {'groupType': None,
#            'groupSubType': None,
#            'numberOfComponents': 0,
#            'groupComponents': None},
#           'petRx': {'eligible': False, 'singleDispense': None},
#           'pglsCondition': None,
#           'preownedCondition': 'None',
#           'imageName': 'Womens-Take-A-Hike-Tshirt-Funny-Outdoor-Adventure-Camping-Graphic-Tee-Heather-Navy-L-Womens-Graphic-Tees_6e00e842-aabc-41ae-9df7-493b18f22e64.f46cbf1b0debfdc4963b19b715f03a8f.jpeg',
#           'fulfillmentBadgeGroups': [{'text': 'Free shipping, arrives ',
#             'slaText': 'in 3+ days',
#             'isSlaTextBold': True,
#             'templates': None,
#             'className': 'dark-gray'}],
#           'weightIncrement': 1,
#           'shortDescription': None,
#           'isEarlyAccessItem': False,
#           'fulfillmentTitle': 'title_shipToHome_not_available',
#           'buyBoxSuppression': False,
#           'vision': {'ageGroup': None, 'visionCenterApproved': False},
#           'badge': {'text': '',
#            'id': '',
#            'type': '',
#            'key': '',
#            'bundleId': ''},
#           'classType': 'VARIANT',
#           'annualEventV2': False,
#           'rewards': None,
#           'seeShippingEligibility': False,
#           'itemType': None,
#           'topResult': None,
#           'isPreowned': False,
#           'imageID': '309245D66D514A708F547CB70FD2EBD2',
#           'aspectInfo': {'name': None,
#            'header': None,
#            'id': None,
#            'snippet': None},
#           'externalInfo': None,
#           'variantCriteria': [],
#           'productLocation': None,
#           'subscription': {'__typename': 'SubscriptionData',
#            'subscriptionEligible': False},
#           'salesUnitType': 'EACH',
#           'additionalOfferCount': None,
#           'isSponsoredFlag': True,
#           'averageRating': None,
#           'arExperiences': {'isARHome': False,
#            'isZeekit': False,
#            'isAROptical': False},
#           'fulfillmentSummary': [{'storeId': '0', 'deliveryDate': None}],
#           'hasCarePlans': False,
#           'imageSize': '290-392',
#           'promoDiscount': None,
#           'quickShopCTALabel': None,
#           'availabilityInNearbyStore': None,
#           'checkStoreAvailabilityATC': False,
#           'eventAttributes': {'priceFlip': False, 'specialBuy': False},
#           'showAtc': False,
#           'similarItems': False,
#           'newConditionProductId': None,
#           'keyAttributes': [],
#           'annualEvent': False,
#           'badges': {'flags': None,
#            'tags': [],
#            'groups': [{'__typename': 'UnifiedBadgeGroup',
#              'name': 'fulfillment',
#              'members': [{'__typename': 'BadgeGroupMember',
#                'id': 'L1053',
#                'key': 'FF_SHIPPING',
#                'memberType': 'badge',
#                'otherInfo': None,
#                'rank': 1,
#                'slaText': 'in 3+ days',
#                'styleId': 'FF_STYLE',
#                'text': 'Free shipping, arrives ',
#                'type': 'LABEL',
#                'templates': None,
#                'badgeContent': None}]}]},
#           'snapEligible': False,
#           'showBuyNow': False,
#           'showExploreOtherConditionsCTA': False,
#           'availabilityStatusV2': {'display': 'In stock', 'value': 'IN_STOCK'},
#           'category': {'path': None},
#           'shouldLazyLoad': False},
#          {'__typename': 'Product',
#           'availabilityStatusDisplayValue': 'In stock',
#           'externalInfoUrl': '',
#           'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/3567947015?athbdg=L1800',
#           'canAddToCart': False,
#           'showOptions': False,
#           'description': "Time and Tru Women's Side Button Crew Neck Sweater, Midweight, Sizes XS-XXXL",
#           'flag': 'Deal',
#           'fulfillmentBadges': [],
#           'fulfillmentSpeed': ['2 days'],
#           'fulfillmentType': 'FC',
#           'id': '2KOPJZKMILIJ',
#           'usItemId': '3567947015',
#           'image': 'https://i5.walmartimages.com/seo/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL_5639ef43-47da-4d6d-a547-945034f17998.c582cb4d3a30edb179eb6e1158504f06.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#           'isOutOfStock': False,
#           'name': "Time and Tru Women's Side Button Crew Neck Sweater, Midweight, Sizes XS-XXXL",
#           'price': 13,
#           'preOrder': {'isPreOrder': False,
#            'streetDateDisplayable': None,
#            'streetDateType': None,
#            'streetDate': None},
#           'priceInfo': {'itemPrice': '$17.98',
#            'linePrice': '$13.00',
#            'wasPrice': '$17.98',
#            'unitPrice': '',
#            'shipPrice': '',
#            'minPriceForVariant': '',
#            'subscriptionPrice': '',
#            'subscriptionString': '',
#            'priceDisplayCondition': '',
#            'finalCostByWeight': False,
#            'submapType': '',
#            'priceRangeString': '',
#            'linePriceDisplay': 'Now $13.00',
#            'eaPricingPreText': '',
#            'memberPriceString': '',
#            'subscriptionPercentage': None,
#            'savingsAmt': 4.98,
#            'minPrice': 0,
#            'savings': 'SAVE $4.98',
#            'subscriptionDualPrice': None,
#            'eaPricingText': ''},
#           'rating': {'averageRating': 4, 'numberOfReviews': 17},
#           'salesUnit': 'EACH',
#           'variantList': [{'name': 'Black Soot',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/51664d8d-d698-47c0-9333-5e890f3a4c90.bd858b16dd3ea92e93c1d8ca466ff53f.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/0ac66449-bf9e-4936-b284-ba666cc1e43f.ad2b8f0ebf4179df3f3fd5318709e19a.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '77RF6FQ9YE93',
#             'usItemId': '2404225454',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/2404225454?variantFieldId=actual_color'},
#            {'name': 'Brilliant Red',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/c928f777-3b6f-4a4a-b053-3a11cdcd6deb.023f860ab976248d1510b5391251f144.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/4bd923e4-4f3c-44df-b446-99281c5efb51.c4da890510b6c62eb527bd6c29acb8a6.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '0YRAHPFG0VID',
#             'usItemId': '3569726653',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/3569726653?variantFieldId=actual_color'},
#            {'name': 'Emerald Forest',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/3eb10ac4-12e3-4607-94a4-fd3676e6b9d0.e9a12a7501135d9d4e5671f34b68a8a4.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/a078b12a-bb02-4598-94b3-1323ee6c60ab.f4634c71fcc843b24aef2712003aabdc.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '38XCA99RSTKC',
#             'usItemId': '1918129475',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/1918129475?variantFieldId=actual_color'},
#            {'name': 'Multi Stripe',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/768f817d-ffd4-4e1b-98ad-a12d7e238116.6df6727c902e77ae459c27c1d42d04c4.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/5639ef43-47da-4d6d-a547-945034f17998.c582cb4d3a30edb179eb6e1158504f06.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '13R2YSDOB4TP',
#             'usItemId': '1935689648',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/1935689648?variantFieldId=actual_color'},
#            {'name': 'Oatmeal Heather',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/7b07b97f-a472-473c-b119-6ae659872549.c83380e05444fcd5889cb8d319f96512.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/27030419-5d25-4cec-8318-24674450c03f.fab9a4da0bd57d2fddad78f391093da0.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '27C0TFMFEL2J',
#             'usItemId': '3112994706',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/3112994706?variantFieldId=actual_color'},
#            {'name': 'Purple Tulip',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/e3aeb05b-821a-46c9-b6b7-1cd2f7185af9.a4e665a61dd2659bbb0ec6f2180e48d0.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/476a034b-0f7b-409a-9f7a-997a92e0c0f7.e0f9613b06c91c54df1838a80c0b6a7a.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '1C9OQTCQ5NU9',
#             'usItemId': '2301793534',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/2301793534?variantFieldId=actual_color'},
#            {'name': 'Shocking Pink',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/d49de3d5-4b07-4fa1-b0f1-05502d9d133c.7d4bf4499ee43c9dc52e608a732fac6b.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/e2c0fa58-7fa6-4cb4-bfbe-9e4f678bfdf0.2e18ecbbbac8229f27e8f7c0625b9981.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '17LC0VAAAIZT',
#             'usItemId': '3108921699',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/3108921699?variantFieldId=actual_color'},
#            {'name': 'Teal Tropic',
#             'swatchImageUrl': 'https://i5.walmartimages.com/asr/4c5026ef-f4a3-48f7-a445-1dc6f2361801.3f45d69619b8b1590fe8324e83602898.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#             'image': 'https://i5.walmartimages.com/asr/d34a84db-2113-4b68-87ad-27e36d97814c.ff3d8fb142255342b68e05c3a3615388.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff',
#             'productId': '16P3AOH6T4EK',
#             'usItemId': '3709428850',
#             'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/3709428850?variantFieldId=actual_color'}],
#           'isVariantTypeSwatch': True,
#           'brand': 'Time and Tru',
#           'offerId': 'EE23DB913A78411E82D4373D87DB044F',
#           'isAtfMarker': False,
#           'sellerId': 'F55CDC31AB754BB68FE0B39041159D63',
#           'sellerName': 'Walmart.com',
#           'quickShop': None,
#           'numberOfReviews': 17,
#           'imageInfo': {'id': 'D61318AFB826401BA74A7E2F2A6D2A96',
#            'name': 'Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL_5639ef43-47da-4d6d-a547-945034f17998.c582cb4d3a30edb179eb6e1158504f06.jpeg',
#            'thumbnailUrl': 'https://i5.walmartimages.com/seo/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL_5639ef43-47da-4d6d-a547-945034f17998.c582cb4d3a30edb179eb6e1158504f06.jpeg?odnHeight=180&odnWidth=180&odnBg=FFFFFF',
#            'size': '290-392'},
#           'type': 'VARIANT',
#           'moqText': None,
#           'specialBuy': False,
#           'pac': None,
#           'priceFlip': False,
#           'earlyAccessEvent': False,
#           'fulfillmentIcon': {'key': 'SAVE_WITH_W_PLUS', 'label': 'Save with'},
#           'groupMetaData': {'groupType': None,
#            'groupSubType': None,
#            'numberOfComponents': 0,
#            'groupComponents': None},
#           'petRx': {'eligible': False, 'singleDispense': None},
#           'pglsCondition': None,
#           'preownedCondition': 'None',
#           'imageName': 'Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL_5639ef43-47da-4d6d-a547-945034f17998.c582cb4d3a30edb179eb6e1158504f06.jpeg',
#           'fulfillmentBadgeGroups': [{'text': 'Shipping, arrives ',
#             'slaText': 'in 2 days',
#             'isSlaTextBold': True,
#             'templates': None,
#             'className': 'dark-gray'}],
#           'weightIncrement': 1,
#           'shortDescription': "Time and Tru Women's Side Button Crew Neck Sweater, Midweight, Sizes XS-XXXL",
#           'isEarlyAccessItem': False,
#           'fulfillmentTitle': 'title_shipToHome_not_available',
#           'buyBoxSuppression': False,
#           'vision': {'ageGroup': None, 'visionCenterApproved': False},
#           'badge': {'__typename': 'BaseBadge',
#            'key': 'HOLIDAY_DEAL',
#            'text': 'Deal',
#            'type': 'LABEL',
#            'id': 'L1800',
#            'styleId': 'PRIMARY_OZARKNOIR_BOLD'},
#           'classType': 'VARIANT',
#           'annualEventV2': False,
#           'rewards': None,
#           'seeShippingEligibility': False,
#           'itemType': None,
#           'topResult': None,
#           'isPreowned': False,
#           'imageID': 'D61318AFB826401BA74A7E2F2A6D2A96',
#           'aspectInfo': {'name': None,
#            'header': None,
#            'id': None,
#            'snippet': None},
#           'externalInfo': None,
#           'displayName': 'options',
#           'variantCriteria': [{'name': 'actual_color',
#             'type': 'LOCATOR',
#             'id': None,
#             'displayName': 'options',
#             'isVariantTypeSwatch': True,
#             'variantList': [{'id': None,
#               'images': ['https://i5.walmartimages.com/asr/0ac66449-bf9e-4936-b284-ba666cc1e43f.ad2b8f0ebf4179df3f3fd5318709e19a.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff'],
#               'name': 'Black Soot',
#               'rank': 10000000,
#               'swatchImageUrl': 'https://i5.walmartimages.com/asr/51664d8d-d698-47c0-9333-5e890f3a4c90.bd858b16dd3ea92e93c1d8ca466ff53f.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#               'availabilityStatus': 'AVAILABLE',
#               'products': ['77RF6FQ9YE93'],
#               'selectedProduct': {'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/2404225454',
#                'usItemId': '2404225454'}},
#              {'id': None,
#               'images': ['https://i5.walmartimages.com/asr/4bd923e4-4f3c-44df-b446-99281c5efb51.c4da890510b6c62eb527bd6c29acb8a6.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff'],
#               'name': 'Brilliant Red',
#               'rank': 10000001,
#               'swatchImageUrl': 'https://i5.walmartimages.com/asr/c928f777-3b6f-4a4a-b053-3a11cdcd6deb.023f860ab976248d1510b5391251f144.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#               'availabilityStatus': 'AVAILABLE',
#               'products': ['0YRAHPFG0VID'],
#               'selectedProduct': {'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/3569726653',
#                'usItemId': '3569726653'}},
#              {'id': None,
#               'images': ['https://i5.walmartimages.com/asr/a078b12a-bb02-4598-94b3-1323ee6c60ab.f4634c71fcc843b24aef2712003aabdc.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff'],
#               'name': 'Emerald Forest',
#               'rank': 10000002,
#               'swatchImageUrl': 'https://i5.walmartimages.com/asr/3eb10ac4-12e3-4607-94a4-fd3676e6b9d0.e9a12a7501135d9d4e5671f34b68a8a4.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#               'availabilityStatus': 'AVAILABLE',
#               'products': ['38XCA99RSTKC'],
#               'selectedProduct': {'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/1918129475',
#                'usItemId': '1918129475'}},
#              {'id': None,
#               'images': ['https://i5.walmartimages.com/asr/5639ef43-47da-4d6d-a547-945034f17998.c582cb4d3a30edb179eb6e1158504f06.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff'],
#               'name': 'Multi Stripe',
#               'rank': 10000003,
#               'swatchImageUrl': 'https://i5.walmartimages.com/asr/768f817d-ffd4-4e1b-98ad-a12d7e238116.6df6727c902e77ae459c27c1d42d04c4.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#               'availabilityStatus': 'AVAILABLE',
#               'products': ['13R2YSDOB4TP'],
#               'selectedProduct': {'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/1935689648',
#                'usItemId': '1935689648'}},
#              {'id': None,
#               'images': ['https://i5.walmartimages.com/asr/27030419-5d25-4cec-8318-24674450c03f.fab9a4da0bd57d2fddad78f391093da0.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff'],
#               'name': 'Oatmeal Heather',
#               'rank': 10000004,
#               'swatchImageUrl': 'https://i5.walmartimages.com/asr/7b07b97f-a472-473c-b119-6ae659872549.c83380e05444fcd5889cb8d319f96512.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#               'availabilityStatus': 'AVAILABLE',
#               'products': ['27C0TFMFEL2J'],
#               'selectedProduct': {'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/3112994706',
#                'usItemId': '3112994706'}},
#              {'id': None,
#               'images': ['https://i5.walmartimages.com/asr/476a034b-0f7b-409a-9f7a-997a92e0c0f7.e0f9613b06c91c54df1838a80c0b6a7a.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff'],
#               'name': 'Purple Tulip',
#               'rank': 10000005,
#               'swatchImageUrl': 'https://i5.walmartimages.com/asr/e3aeb05b-821a-46c9-b6b7-1cd2f7185af9.a4e665a61dd2659bbb0ec6f2180e48d0.jpeg?odnHeight=30&odnWidth=30&odnBg=ffffff',
#               'availabilityStatus': 'AVAILABLE',
#               'products': ['1C9OQTCQ5NU9'],
#               'selectedProduct': {'canonicalUrl': '/ip/Time-and-Tru-Women-s-Side-Button-Crew-Neck-Sweater-Midweight-Sizes-XS-XXXL/2301793534',
#                'usItemId': '2301793534'}},
#              {'id': None,
# ...
#         'spBbTranche2Enable': True,
#         'ipBbLazyLoadingEnable': False,
#         'phSkMeasure3PEnable': True,
#         'spSbaMeasure1PEnable': True,
#         'hpGpbFs3Measure1PEnable': True,
#         'dspMultiProcessingEnable': True,
#         'ipSkDSPEnable': True,
#         'spSvRenderEnable': True,
#         'ipMq1Version': '',
#         'spSvYabasVideoClickEnable': True,
#         'ipGalTopMeasure3PEnable': False,
#         'spSvReqEnable': True,
#         'hpTpFs1FeedbackEnable': False,
#         'adCategoryTakeoverCheck': True,
#         'hpGpbFs2Measure3PEnable': True,
#         'shpSkDSPEnable': True,
#         'enableVideoUIErrorState': True,
#         'spMq2DSPEnable': True,
#         'ipBr1ReqEnable': True,
#         'hpTpFs2DSPEnable': True,
#         'ipGalMiddleMeasure3PEnable': False}},
#       'search': {'_all_': {'splitDataCallLimit': 10,
#         'enableExternalInfoUrl': True,
#         'atfDwebGridCount': 10,
#         'enableFlattenedFitment': False,
#         'enableHotPac': False,
#         'fitmentTopicPageEnable': True,
#         'fetchTimeoutMs': 7000,
#         'mwebGridProductCount': 8,
#         'enableNewPriceFormatType': 2,
#         'enableItemStackLazyLoading': False,
#         'enablePortableFacets': True,
#         'enableVariantsPagination': True,
#         'displayMobileATCJustified': True,
#         'displayMobileATCLeftAligned': False,
#         'showARExperienceBadging': False,
#         'enableSearchPageSSR': True,
#         'enableProductTileRedesignBadge': False,
#         'showAROpticalBadge': False,
#         'enableFacetedFilterBarVarC': False,
#         'enableSeoHeaderTitleOverride': True,
#         'enableProductTileRedesignAttributes': False,
#         'enableShopByModule': True,
#         'postProcessedQueryEnable': True,
#         'enableMaxWidth': True,
#         'enableTopNavUpdateGQLCall': True,
#         'seoModulesEnable': True,
#         'enableFIDLogging': True,
#         'subscriptionHeaderImage': 'https://i5.walmartimages.com/dfw/63fd9f59-66cc/af8fd81e-b326-47e6-b1b5-f3dd515182e6/v1/wplus-logo-blue.svg',
#         'enableSubscriptionFeature': True,
#         'enableProductTileRedesign': False,
#         'enableGoldenReview': False,
#         'enableScrollBasedLazyLoading': False,
#         'enableFacetedFilterBar': False,
#         'enableAspectRecommendation': False,
#         'viewportThresholdMobile': 0.25,
#         'enableFacetExpansion': False,
#         'enableFulfillmentMethodDemo': False,
#         'enablePAC': True,
#         'enableMSP': False,
#         'dwebGridProductCount': 20,
#         'subscriptionZeroPercentDiscountBadgeEnabled': True,
#         'enableLeftHandNav': True,
#         'atfMwebListCount': 2,
#         'enableGIC': True,
#         'enableLCPSingleImagePrefetch': False,
#         'tileTakeOverSearch': True,
#         'enableLCPHighFetchPriority': True,
#         'enableSeoMetaDescOverride': True,
#         'enableVariantItemSmile': True,
#         'enableLHNCategoryTree': False,
#         'lcpImageQuality': '1',
#         'searchPersistentFilterEnable': False,
#         'enableLCPSingleImagePrefetchScaleFallback': False,
#         'enableSearchSSRParallelQueries': False,
#         'enableSimilarItems': True,
#         'enableGenericSeoFAQ': True,
#         'partialRenderEnable': True,
#         'tileTakeOver': True,
#         'enableDynamicFitment': True,
#         'bannerModulesEnableSearch': True,
#         'enableReducedVariantList': False,
#         'hideProductTileWhiteSpace': False,
#         'omitSortFacetParam': False,
#         'fetchItemsV2Enable': True,
#         'enableNewStackedRecallNoResult': True,
#         'threeColumnGrid': False,
#         'enableFashionTopNav': False,
#         'enableFulfillmentBadge': True,
#         'enableTopNavItemStack': False,
#         'enableFacetCount': True,
#         'enableNUpsSearch': True,
#         'enableGrapqlQueryParams': True,
#         'bookSlotPersistentFilterEnable': False,
#         'enableRemoveEmptyProductFlagRows': False,
#         'enableViewportThreshold': True,
#         'enableSearchSkinnyBanner': False,
#         'enableInvalidateGICQuery': True,
#         'viewportThresholdDesktop': 0.25,
#         'enablePaginationIO': False,
#         'showFilterTooltip': False,
#         'lazyLoadMS': 0,
#         'defaultNoOfQuestionsToShow': 3,
#         'smileVariation': 2,
#         'enableOLImageSize': True,
#         'fitmentModulesEnable': True,
#         'mwebListProductCount': 4,
#         'enableStickyDisclaimerBar': False,
#         'enableAOSPanel': False,
#         'enableLHNFilterUpdateGQLCall': True,
#         'enableMaxOrderQuantity': False,
#         'enableValuePricing': True,
#         'enableProductTileRedesignImage': False,
#         'enableColorSwatch': True,
#         'enableCleanPrice': False,
#         'enableSpecificLazyFeature': '',
#         'enableRemovePadding': False,
#         'enableDeprioritizeTailImages': False,
#         'enableSearchHotBadge': False,
#         'enableAOS': False,
#         'removeLHNDuplicates': False,
#         'listViewEnum': 1,
#         'topicPageSortBy': 'best_match',
#         'enableReducedItemData': False,
#         'enableSplitDataCall': False,
#         'displayMobileATCRightAligned': False,
#         'bannerModulesEnable': True,
#         'clientFetchTimeoutMs': 15000,
#         'imageSizeEnum': 3,
#         'enableSecondaryStackType': 0,
#         'enableRemoveEmptyProductVariantRows': False,
#         'enableAccInstallation': True,
#         'productTile2xImageDimensions': '612,612',
#         'enableStylesheetsForInlineStyles': False,
#         'enableTopicPageToDGF': False,
#         'secondaryQuerySwitch': False,
#         'enableRelatedSearches': True,
#         'enableWPlusBadge': False,
#         'enableDynamicFilters': False,
#         'clothingSizeFacetEnhancementsVariation': 1,
#         'enableSearchDollarSavingsBadge': False,
#         'pricingDisclaimerText': 'Price when purchased online',
#         'skipGICIntent': True,
#         'enableWPlusBadgeByCategories': '',
#         'enableGridLayoutForFashion': False,
#         'enableSwatchesOnTopicPage': True,
#         'discoveryTopicABUrls': '',
#         'enableProductTile2xImageDimension': False,
#         'enableIntersectedSearchResults': False,
#         'topResultSubHeader': '',
#         'enableBrowsingHistory': False,
#         'topResultHeader': '',
#         'enableTopicDiscoveryPhase': False,
#         'interesectedResultsBottomMargin': 1.5,
#         'enableRelatedSearchHorizontalPills': True,
#         'enableInRiverNudge': False,
#         'enableNUps': True,
#         'enableLimitedLinesInTitlesByCategories': 'fashion',
#         'enableVisionCenterBadgeSearch': True,
#         'enableSingleItemTopResult': False,
#         'enablePricingDisclaimer': True,
#         'enableVariantDynamicText': True,
#         'enableEaViolatorBannerV2': False,
#         'searchPageBuyNowType': 0,
#         'enableLimitedLinesInTitles': False,
#         'enableHighResImagesForSearch': False}}},
#      'membership': {'data': {'shouldShowWplusLogo': False}}},
#     'enableGqlCsrRedirect': True,
#     'nonce': '79MNnNYArYsgUFpK',
#     'persistedQueriesConfig': {'allowList': [''],
#      'blackList': [''],
#      'enableAllowList': False,
#      'enablePersistedQueries': True},
#     'dehydratedSearchCv': {'enableLCPHighFetchPriority': True,
#      'enableLCPSingleImagePrefetch': False},
#     'countryRegion': {'countryCode': 'US', 'regionCode': 'NJ'},
#     'adSessionId': '61fb567e52643d9509a282b50efd6244',
#     'excludeBeacon': False,
#     'isNextPublicMocksEnabled': False}},
#   'gip': True,
#   'defaultLocale': 'en',
#   'locales': ['en', 'es'],
#   'page': '/search',
#   'isFallback': False,
#   'customServer': True,
#   'runtimeConfig': {'nxApplicationName': 'US-JOURNEY',
#    'isDev': False,
#    'enableLatencyTrace': True,
#    'tenant': 'WM_GLASS',
#    'vid': 'oaoh',
#    'tenantV2': {'bu': 'WALMART-US', 'mart': 'B2C'},
#    'mockURL': 'http://mock-backend.dev.walmart.com/',
#    'mock': True,
#    'endpointMappings': {'operations': {'query configuration': 'cegateway',
#      'query RewardsHistoryPage': 'cegateway',
#      'query ContentPage': 'cegateway',
#      'query BrandPage': 'cegateway',
#      'query checkItemCartEligibility': 'cecxo',
#      'mutation MergeAndGetCart': 'cecxo',
#      'query getGuestOrder': 'cegateway',
#      'query PurchaseHistory': 'cecph',
#      'mutation NotifyCapOneBannerSnooze': 'cegateway',
#      'mutation CancelOrder': 'cecph',
#      'query LastCallPage': 'cegateway',
#      'query AdV2Display': 'adsgateway',
#      'query GetCommPreference': 'cegateway',
#      'query PurchasedProtectionPlans': 'cecph',
#      'query PurchasedProtectionPlansV2': 'cecph',
#      'query ProtectionPlanDetail': 'cecph',
#      'query subscriptions': 'cegateway',
#      'query NodeDetailQuery': 'cegateway',
#      'query NearbyNodesQuery': 'cegateway',
#      'query LocalStoreContentQuery': 'cegateway',
#      'query CartSubstitutions': 'cegateway',
#      'query CartShopSimilar': 'cegateway',
#      'query GetEarlyAccessLearnMoreData': 'ceaccount',
#      'query PostCartLoadPage': 'cegateway',
#      'query SearchStore': 'cegateway',
#      'query LocalStoreCategoryContent': 'cegateway',
#      'query nodeDetails': 'cegateway',
#      'query storeFinderNearbyNodesQuery': 'cegateway',
#      'mutation CreateInsuranceSalesLead': 'wellness',
#      'mutation setPickup': 'cecxo',
#      'query getCart': 'cegateway',
#      'query feedShowCategories': 'cegateway',
#      'query feedsByStatus': 'cegateway',
#      'query feedShow': 'cegateway',
#      'query feedsByStatusPaginated': 'cegateway',
#      'query SavingsDashboard': 'cegateway',
#      'mutation cancelReturnOrder': 'cereturns',
#      'query GetDeliveryPreferences': 'cegateway',
#      'query LensCustomizationProductIdmlQuery': 'cepdp'},
#     'queryStrings': {'step=cart': 'cecxo',
#      'step=bookslot': 'cecxo',
#      'entitytype=*': 'ceorders',
#      'state=*': 'ceorders',
#      'source=*': 'ceorders'},
#     'pages': {'*': 'cegateway',
#      '/': 'cegateway',
#      '/hp-redesign': 'cegateway',
#      '/404': 'cegateway',
#      '/acc/[id]': 'cegateway',
#      '/acc/schedule-oil-change': 'cecxo',
#      '/account/*': 'cegateway',
#      '/all-departments': 'cegateway',
#      '/browse/*': 'cegateway',
#      '/c/[...seo]': 'cegateway',
#      '/c/auto-directory/*': 'cegateway',
#      '/ci-control': 'cegateway',
#      '/cp/[...categoryParams]': 'cegateway',
#      '/content/[...categoryParams]': 'cegateway',
#      '/brand/[...brandParams]': 'cegateway',
#      '/brand/branddirectory': 'cegateway',
#      '/help/*': 'cegateway',
#      '/i/*': 'cegateway',
#      '/ip/[...itemParams]': 'cegateway',
#      '/lists/*': 'cegateway',
#      '/my-items': 'cegateway',
#      '/my-registries': 'cegateway',
#      '/shop/*': 'cegateway',
#      '/shop/[...seo]': 'cegateway',
#      '/nonprofits/*': 'cegateway',
#      '/orders/*': 'ceorders',
#      '/partner/plus/*': 'cegateway',
#      '/plus/*': 'cegateway',
#      '/wp/*': 'cegateway',
#      '/product/[...itemParams]': 'cegateway',
#      '/registry/*': 'cegateway',
#      '/reviews/*': 'cegateway',
#      '/search/*': 'cegateway',
#      '/seller/*': 'cegateway',
#      '/services': 'cegateway',
#      '/store': 'cegateway',
#      '/store/[storeId]': 'cegateway',
#      '/store/[storeId]/[...contentType]': 'cegateway',
#      '/sparkgood/*': 'cegateway',
#      '/organizations/*': 'cegateway',
#      '/thankyou': 'cecxo',
#      '/thankyou/pindrop': 'cecxo',
#      '/topic/[...seo]': 'cegateway',
#      '/tp/*': 'cegateway',
#      '/update-payment-method-form': 'cegateway',
#      '/update-payment-method': 'cegateway',
#      '/wallet/associate-discount': 'cegateway',
#      '/subscriptions/manage': 'cegateway',
#      '/cart': 'cecxo',
#      '/pac': 'cecxo',
#      '/updatecart': 'cecxo',
#      '/shopwithme/*': 'cegateway',
#      '/rewards-history': 'cegateway',
#      '/global/*': 'cegateway',
#      '/global/[...seo]': 'cegateway',
#      '/live': 'cegateway',
#      '/live-next': 'cegateway',
#      '/live-next/browse': 'cegateway',
#      '/savings': 'cegateway',
#      '/cash-overview': 'cegateway',
#      '/in-store-wifi/*': 'cegateway',
#      '/live-next/shows': 'cegateway',
#      '/g/*': 'cegateway',
#      '/g/[...seo]': 'cegateway',
#      '/gic': 'cegateway',
#      '/fittingroom': 'cegateway',
#      '/protection-plans': 'cecph',
#      '/inhome/*': 'cegateway',
#      '/user-query': 'cecxo',
#      '/assistant': 'cecxo'}},
#    'googleMaps': {'checkAddressAPIKey': 'AIzaSyCX5gh3yoq4316wUDxRpljFOwWA6_-BEMg',
#     'addressAPIKey': 'AIzaSyBIAnB1a3UejjFVRNtszhaEE8yrKySRTEo',
#     'geoCodingAPIKey': 'AIzaSyBvv63fBVZ1RtNJLGkN9XCFE1WfVl0o1HY',
#     'riseMapAPIKey': {'dev': 'AIzaSyA9K6pBcYvCp4_FxKHsPi-JDJfvcvSbtp0',
#      'defaultKey': 'AIzaSyA0Gi6N7afDzAqBiPI3MlWDMaaxC5xKldM'}},
#    'membershipConfig': {'showWPlusBanner': True},
#    'pulseBeacon': {'enable': True,
#     'hostname': 'i5.walmartimages.com',
#     'bd': 'beacon.walmart.com',
#     'bh': 'beacon.lightestwithqm.walmart.com',
#     'hostWithQM': 'beacon.lightestwithqm.walmart.com',
#     'hostWithoutQM': 'beacon.lightest.walmart.com',
#     'photoHost': 'beacon.photowithqm.walmart.com',
#     'photoHostWithoutQM': 'beacon.photo.walmart.com'},
#    'perimeterX': {'enable': True,
#     'initScript': 'https://www.walmart.com/px/PXu6b0qd2S/init.js'},
#    'identity': {'context': {'signOutUrl': '/account/logout',
#      'signInPathname': '/account/login',
#      'createAccountPathname': '/account/signup',
#      'tenants': [{'host': {'stage': 'business-stage.walmart.com',
#         'teflon': 'business-teflon.walmart.com',
#         'production': 'business.walmart.com'},
#        'mart': 'B2B',
#        'templates': ['B2BSignUpPage',
#         'B2BSignInPage',
#         'B2BSignInWithPasswordOnlyPage',
#         'B2BSignInWithOTPChoicePage',
#         'B2BSignInWithOTPOnlyPage']}],
#      'marketingEmails': True,
#      'rightsReservedText': '',
#      'footerOptions': [],
#      'termsLink': '',
#      'privacyLink': ''},
#     'authFrameRoutes': {'frame': '/account/login',
#      'reauthFrame': '/account/login',
#      'gxoSignup': '/account/signup/gxo',
#      'gxoSignin': '/account/login'}},
#    'threatMetrix': {'enable': True},
#    'paymentsPageUrl': 'https://wallet.walmart.com/payments?wv=main',
#    'paymentsChooserPageUrl': 'https://wallet.walmart.com/payments/chooser',
#    'walletPageUrl': 'https://wallet.walmart.com/payments/wallet',
#    'ads': {'env': 'production',
#     'host': 'https://www.walmart.com',
#     'moatId': 'WALMART_DISPLAY_S2S1',
#     'moatVideoId': 'WALMART_VIDEO_S2S1'},
#    'moatIvt': 'https://www.walmart.com/swag/v2/ip-rd',
#    'rewardsTravelUrl': 'https://walmartplustravel.com/trips',
#    'appVersion': 'us-web-1.104.4-c58d431eba530d8e7fb2d4a90a93a0a51ed5a9ef-1113',
#    'appSha': 'c58d431eba530d8e7fb2d4a90a93a0a51ed5a9ef',
#    'profile': 'production',
#    'tmxOrgId': 'hgy2n0ks',
#    'dataCenter': 'wus2',
#    'queryContext': {'appVersion': 'us-web-1.104.4-c58d431eba530d8e7fb2d4a90a93a0a51ed5a9ef-1113',
#     'gql': {'endpointsByName': {'ceaccount': '/orchestra/account/graphql',
#       'cecxo': '/orchestra/cartxo/graphql',
#       'cecph': '/orchestra/cph/graphql',
#       'adsgateway': '/swag/graphql',
#       'aroundme': '/around-me/graphql',
#       'ceorders': '/orchestra/orders/graphql',
#       'cegateway': '/orchestra/home/graphql',
#       'cepdp': '/orchestra/pdp/graphql',
#       'wellness': 'https://developer.api.us2.walmart.com/api-proxy/service/hw/wellnessplusservice/v1/graphql',
#       'cereturns': '/orchestra/orders/graphql'}},
#     'rest': {'endpointsByName': {'cereturns': '/orchestra/api/returns',
#       'ceaccount': '/orchestra/api/account',
#       'cehelp': '/orchestra/help/api',
#       'cehelpchat': '/orchestra/helpChat/api',
#       'ceidentity': '/orchestra/account/electrode/api/identity',
#       'typeahead': '/typeahead/v3/complete',
#       'espvalidation': '/esp/prepaid/v1/plans',
#       'warppaymentoptions': '/orchestra/api/online/variantbasic/item',
#       'cewarp': '/orchestra/api/warp',
#       'ceccm': '/orchestra/api/ccm/v2/bootstrap',
#       'ceccm2': '/orchestra/api/ccm/v2/bootstrap',
#       'cewireless': '/orchestra/api/wireless',
#       'storeservices': '/graphql',
#       'fuelPrices': '/graphql',
#       'feedbackSubmit': '/orchestra/api/customer-survey/submit',
#       'quimbyMobile': '/orchestra/api/tempo',
#       'shopwithme': '/feeds'}}}},
#   'scriptLoader': []}}

# %%
## Charts
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.relplot(data=df, x="item_price", y="reviews")
plt.title("Corrilation between price and number of reviews")

## there doesn't seem to be any corrilation between the price of an item and the number of reviews that are left on an item
# Out:
# Text(0.5, 1.0, 'Corrilation between price and number of reviews')

# %%
import matplotlib.pyplot as plt
SellerName_count = df['seller_name'].value_counts()
plt.pie(SellerName_count, labels=SellerName_count.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Types of Sellers')
# Out:
# Text(0.5, 1.0, 'Types of Sellers')

# %%
reviews_per_seller = df.groupby('seller_name')['reviews'].sum()

# Sorting the sellers by total reviews and selecting the top 5 sellers
top_5_sellers = reviews_per_seller.nlargest(5)

# Plotting a pie chart for the top 5 sellers
plt.figure(figsize=(10, 8))
plt.pie(top_5_sellers, labels=top_5_sellers.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Sellers by Total Reviews')
plt.show()

# %%
average_prices = df.groupby('seller_name')['item_price'].mean()
average_prices.plot(kind='bar', color='skyblue')
plt.xlabel('Seller Name')
plt.xlabel('Average Price')
plt.title('Average Prices Based on the Seller')
# Out:
# Text(0.5, 1.0, 'Average Prices Based on the Seller')

# %%
## This is the same as the chart ablove but it is only showing the top 5 price averages
average_prices = df.groupby('seller_name')['item_price'].mean()
top_5_avg_prices = average_prices.sort_values(ascending=False).head(5)
top_5_avg_prices.plot(kind='bar', color='lightblue')
plt.xlabel('Seller Name')
plt.xlabel('Average Price')
plt.title('Average Prices Based on the Seller')
# Out:
# Text(0.5, 1.0, 'Average Prices Based on the Seller')

# %%
# Developed a correlation matrix no including availability because that that data type is boolean which throws off our findings
selected_columns = ['item_price', 'avg_rating', 'reviews']
subset_df = df[selected_columns]
cor_matrix = subset_df.corr()
sns.heatmap(cor_matrix, annot = True, cmap = "coolwarm", fmt = ".2f", linewidths = .5)
plt.title('Correlation Matrix Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Heatmap')

# %%
# Created a box plot to represent the top 3 sellers
top_sellers = df['seller_name'].value_counts().nlargest(3).index
df_top_sellers = df[df['seller_name'].isin(top_sellers)]
sns.boxplot(x='seller_name', y='item_price', data = df_top_sellers)
plt.title('Distribution of Prices for Top 3 Sellers')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices for Top 3 Sellers')
